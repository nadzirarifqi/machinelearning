# %% [markdown]
# <a href="https://colab.research.google.com/github/nadzirarifqi/machinelearning/blob/main/ML_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

patients_file_path = 'patients.csv'
patients_data = pd.read_csv(patients_file_path)
patients_data.columns
# Out:
# Index(['patient_id', 'name', 'age', 'arrival_date', 'departure_date',
#        'service', 'satisfaction'],
#       dtype='object')

# %%
patients_data = patients_data.dropna(axis=0)
patients_data.head()
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76

# %%
y = patients_data.satisfaction

# %%
patients_features = ['name', 'age', 'arrival_date', 'departure_date', 'service']

# %%
X = patients_data[patients_features]

# %%
X.describe()
# Out:
#                age
# count  1000.000000
# mean     45.337000
# std      25.999912
# min       0.000000
# 25%      23.000000
# 50%      46.000000
# 75%      68.000000
# max      89.000000

# %%
X.head()
# Out:
#                 name  age arrival_date departure_date           service
# 0  Richard Rodriguez   24   2025-03-16     2025-03-22           surgery
# 1     Shannon Walker    6   2025-12-13     2025-12-14           surgery
# 2       Julia Torres   24   2025-06-29     2025-07-05  general_medicine
# 3    Crystal Johnson   32   2025-10-12     2025-10-23         emergency
# 4        Garrett Lin   25   2025-02-18     2025-02-25               ICU
